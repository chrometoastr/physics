# %% [markdown]
# # GR Prerequisites — Notebook 0: Setup
#
# ## Goals
# - Keep derivations reproducible (symbolic checks where possible)
# - Build a personal reference library (definitions + canonical examples)
#
# ## Conventions
# - Metric signature: (-,+,+,+) unless stated otherwise
# - Einstein summation: repeated upper/lower indices summed
# - Units: c = 1 when convenient

# %%
# Suggested imports (keep it consistent across notebooks)
import sympy as sp
sp.init_printing()

import numpy as np

# %% [markdown]
# ## Notebook structure (recommended)
# 1. Key definitions (bullet list)
# 2. Theorems / identities (with conditions)
# 3. One canonical worked example
# 4. Exercises
# 5. GR connection: why this matters later
