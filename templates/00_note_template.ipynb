# %% [markdown]
# # Topic Title (Course/Unit)
#
# **Last updated:** YYYY-MM-DD
# **Prereqs:** (e.g., derivatives, vectors)
# **Tags:** #mechanics #linear-algebra
#
# ## Goals
# - Goal 1
# - Goal 2
# - Goal 3

# %%
import numpy as np
import matplotlib.pyplot as plt

# If you keep reusable helpers in src/, this makes them importable from the repo root:
# (Run notebooks from the repo root, or adjust as needed.)
import sys
from pathlib import Path
repo_root = Path.cwd().parents[0] if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(repo_root))

# from src.constants import *   # optional
# from src.utils import savefig # optional

# %% [markdown]
# ## Key definitions
#
# - Definition 1:
#   \[
#   ...
#   \]
# - Definition 2:
#   \[
#   ...
#   \]

# %% [markdown]
# ## Core result
#
# **Claim:** (state the main equation/result)
#
# **Assumptions:**
# 1. ...
# 2. ...
#
# **Interpretation:** what it means physically / geometrically.

# %% [markdown]
# ## Derivation / proof
#
# 1. Start from:
#    \[
#    ...
#    \]
# 2. Substitute:
#    \[
#    ...
#    \]
# 3. Conclude:
#    \[
#    ...
#    \]
#
# **Sanity checks**
# - Units / dimensions:
# - Limiting cases:
# - Symmetry / invariance:

# %% [markdown]
# ## Worked example
#
# **Problem:** (short statement)
#
# **Solution outline:**
# 1. ...
# 2. ...
#
# **Final answer:**
# \[
# ...
# \]

# %%
# Replace with your example: numeric check, visualization, etc.
x = np.linspace(0, 10, 500)
y = np.sin(x)

plt.figure()
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Example plot")
plt.show()

# %% [markdown]
# ## Common pitfalls / conventions
#
# - Sign conventions (e.g., metric signature, Fourier transform conventions)
# - Missing constants (2π, ε₀, c, ħ)
# - Coordinate system assumptions

# %% [markdown]
# ## Summary (1–5 bullets)
# - ...
# - ...
#
# ## Flashcards / recall prompts
# - Q: What conditions are required for ...?
# - Q: In the limit ..., what happens to ...?

# %% [markdown]
# ## References
# - Textbook: Author, *Title*, section X.Y
# - Paper/notes link: ...
